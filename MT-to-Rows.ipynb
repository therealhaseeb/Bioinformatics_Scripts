# %%
import hail as hl
hl.init()
# Out:
# Running on Apache Spark version 2.4.5
# SparkUI available at http://hail-m.us-central1-f.c.cncd-cncd.internal:4040
# Welcome to
#      __  __     <>__
#     / /_/ /__  __/ /
#    / __  / _ `/ / /
#   /_/ /_/\_,_/_/_/   version 0.2.61-3c86d3ba497a
# LOGGING: writing to /hail-20210201-1019-0.2.61-3c86d3ba497a.log

# %%
data = hl.import_vcf("gs://pgr-wgs-8k/VCF/vcf_DP10/pgr7k_chr21.vcf.gz", reference_genome="GRCh38", force_bgz=True)
data.rows().show()
# Out:
# 2021-02-01 10:21:21 Hail: INFO: Coerced sorted dataset
# +---------------+------------+----------------+----------+----------------+
# | locus         | alleles    | rsid           |     qual | filters        |
# +---------------+------------+----------------+----------+----------------+
# | locus<GRCh38> | array<str> | str            |  float64 | set<str>       |
# +---------------+------------+----------------+----------+----------------+
# | chr21:5025532 | ["G","C"]  | NA             | 3.50e+01 | {"SVM","MIS2"} |
# | chr21:5030088 | ["C","T"]  | "rs1455320509" | 4.80e+01 | {"SVM","MIS2"} |
# | chr21:5030105 | ["C","A"]  | "rs1173141359" | 5.20e+01 | {"SVM","MIS2"} |
# | chr21:5030154 | ["T","C"]  | "rs1461284410" | 7.00e+00 | {"SVM","MIS2"} |
# | chr21:5030173 | ["G","C"]  | "rs1371194619" | 9.00e+00 | {"SVM","MIS2"} |
# | chr21:5030192 | ["A","G"]  | "rs1172282560" | 5.00e+00 | {"MIS2"}       |
# | chr21:5030201 | ["A","C"]  | NA             | 4.60e+01 | {"MIS2"}       |
# ...

# %%
hl.export_vcf(data.rows(), "gs://test1haseeb/UTRannotator-output/data/pgr-wgs-8k-chr1-variants.vcf")
# Out:
# 2021-02-01 10:40:07 Hail: INFO: Coerced sorted dataset
# 2021-02-01 10:41:37 Hail: INFO: merging 51 files totalling 12.5G...
# 2021-02-01 10:43:34 Hail: INFO: while writing:
#     gs://test1haseeb/UTRannotator-output/data/pgr-wgs-8k-chr1-variants.vcf
#   merge time: 1m57.2s
