# %%
import hail as hl
hl.init()
# Out:
# 2020-12-11 06:32:49 Hail: INFO: SparkUI: http://hailpy1-m.us-central1-b.c.cncd-cncd.internal:4040
# Running on Apache Spark version 2.4.5
# SparkUI available at http://hailpy1-m.us-central1-b.c.cncd-cncd.internal:4040
# Welcome to
#      __  __     <>__
#     / /_/ /__  __/ /
#    / __  / _ `/ / /
#   /_/ /_/\_,_/_/_/   version 0.2.59-63cf625e29e5
# LOGGING: writing to /hail-20201211-0632-0.2.59-63cf625e29e5.log

# %%
data = hl.read_matrix_table("gs://pgr-wes-30k-mt/Complete_Annotations/Promis30_chr22_VEP_DB.mt")
data.rows().show()
# Out:
# +---------------+---------------+------+----------+
# | locus         | alleles       | rsid |     qual |
# +---------------+---------------+------+----------+
# | locus<GRCh37> | array<str>    | str  |  float64 |
# +---------------+---------------+------+----------+
# | 22:16157258   | ["C","G"]     | NA   | 1.35e+04 |
# | 22:16157261   | ["G","A"]     | NA   | 3.16e+01 |
# | 22:16157263   | ["C","T"]     | NA   | 5.31e+04 |
# | 22:16157264   | ["G","A"]     | NA   | 9.46e+04 |
# | 22:16157275   | ["G","A","T"] | NA   | 9.87e+03 |
# | 22:16157277   | ["G","A"]     | NA   | 5.03e+03 |
# | 22:16157278   | ["G","A"]     | NA   | 9.28e+03 |
# | 22:16157281   | ["C","G"]     | NA   | 8.09e+04 |
# | 22:16157282   | ["G","T"]     | NA   | 8.95e+03 |
# | 22:16157290   | ["C","T"]     | NA   | 1.72e+03 |
# +---------------+---------------+------+----------+
#
# +--------------------------------+--------------+---------------------+
# ...

# %%
sample_ids = data.s.collect()

# %%
type(sample_ids)
# Out:
# list

# %%
import pandas as pd

pd.DataFrame(sample_ids, columns=['30k_Sample_IDs']).to_excel("30k_Sample_IDs.xlsx")
# !ls
# Out:
# 30k_Sample_IDs.xlsx			    mnt
# bin					    opt
# boot					    proc
# dev					    root
# etc					    run
# hadoop					    sbin
# hail-20201211-0619-0.2.59-63cf625e29e5.log  sparkmonitor_kernelextension.log
# hail-20201211-0632-0.2.59-63cf625e29e5.log  srv
# home					    sys
# initrd.img				    tmp
# initrd.img.old				    usr
# lib					    var
# lib64					    vmlinuz
# lost+found				    vmlinuz.old
# media

# %%
# !gsutil cp 30k_Sample_IDs.xlsx gs://pgr-wes-30k-mt/
# Out:
# Copying file://30k_Sample_IDs.xlsx [Content-Type=application/vnd.openxmlformats-officedocument.spreadsheetml.sheet]...
# - [1 files][493.0 KiB/493.0 KiB]
# Operation completed over 1 objects/493.0 KiB.
